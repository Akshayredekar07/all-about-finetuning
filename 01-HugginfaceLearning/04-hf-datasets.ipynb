# %%
import os
from huggingface_hub import login
from dotenv import load_dotenv
load_dotenv()

os.environ["HF_TOKEN"] = os.getenv("HF_WRITE_TOKEN", "")
login(token=os.environ["HF_TOKEN"])
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
import os
from huggingface_hub import login, HfApi
from dotenv import load_dotenv

load_dotenv()

os.environ["HF_TOKEN"] = os.getenv("HF_WRITE_TOKEN", "")
login(token=os.environ["HF_TOKEN"])

REPO_ID   = "akshayredekar45/first-dataset"  
DATA_DIR  = "data" # local folder containing files
REPO_TYPE = "dataset"

api = HfApi()

# Create the repo if it doesn't exist yet
api.create_repo(repo_id=REPO_ID, repo_type=REPO_TYPE, exist_ok=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# RepoUrl('https://huggingface.co/datasets/akshayredekar45/first-dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='akshayredekar45/first-dataset')

# %%
# Supported extensions to upload
SUPPORTED_EXTENSIONS = {".txt", ".parquet", ".csv", ".jsonl"}

# Walk the data/ directory and upload every matching file
for filename in os.listdir(DATA_DIR):
    ext = os.path.splitext(filename)[1].lower()
    if ext not in SUPPORTED_EXTENSIONS:
        continue

    local_path = os.path.join(DATA_DIR, filename)
    # Keeps the file under data/ on the Hub as well
    path_in_repo = f"data/{filename}"

    print(f"Uploading {local_path}  →  {REPO_ID}/{path_in_repo} ...")
    api.upload_file(
        path_or_fileobj=local_path,
        path_in_repo=path_in_repo,
        repo_id=REPO_ID,
        repo_type=REPO_TYPE,
    )
    print(f"  ✓ {filename} uploaded successfully")

print("\nAll files uploaded!")
# Out:
# Uploading data/data.csv  →  akshayredekar45/first-dataset/data/data.csv ...
#   ✓ data.csv uploaded successfully
# Uploading data/test.csv  →  akshayredekar45/first-dataset/data/test.csv ...
#   ✓ test.csv uploaded successfully
# Uploading data/train.csv  →  akshayredekar45/first-dataset/data/train.csv ...
#   ✓ train.csv uploaded successfully
# Uploading data/data.parquet  →  akshayredekar45/first-dataset/data/data.parquet ...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
#   ✓ data.parquet uploaded successfully
# Uploading data/data.txt  →  akshayredekar45/first-dataset/data/data.txt ...
#   ✓ data.txt uploaded successfully
# Uploading data/data.jsonl  →  akshayredekar45/first-dataset/data/data.jsonl ...
#   ✓ data.jsonl uploaded successfully
#
# All files uploaded!
